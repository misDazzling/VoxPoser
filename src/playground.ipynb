# %%
import openai
from arguments import get_config
from interfaces import setup_LMP
from visualizers import ValueMapVisualizer
from envs.rlbench_env import VoxPoserRLBench
from utils import set_lmp_objects
import numpy as np
from rlbench import tasks

openai.api_key = 'sk-Z9YpcPjL0Ie6BuwmC59031640f794aA39d65DeF13f1aEc51'  # set your API key here
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Setup

# %%
config = get_config('rlbench')
# uncomment this if you'd like to change the language model (e.g., for faster speed or lower cost)
# for lmp_name, cfg in config['lmp_config']['lmps'].items():
#     cfg['model'] = 'gpt-3.5-turbo'

# initialize env and voxposer ui
visualizer = ValueMapVisualizer(config['visualizer'])
env = VoxPoserRLBench(visualizer=visualizer)
lmps, lmp_env = setup_LMP(env, config, debug=False)
voxposer_ui = lmps['plan_ui']
# Out:
# ##################################################
# ## voxel resolution: [0.0105 0.0131 0.01  ]
# ##################################################

# %% [markdown]
# ## Playground
#
# By default we use one of the instructions that come with each task. However, you may treat each task as simply a scene initialization from RLBench, and feel free to try any task you can come up with for the scene.
#
# Note:
# - Whether an instruction can be executed or not depends on 1) whether relevant objects are available, and 2) capabilities of the overall algorithm.
# - Each execution may produce one or more visualizations. You may view them in "./visualizations/" folder.
# - The prompts are adapted with minimal change from the real-world environment in the VoxPoser paper. If a task failure is due to incorrect code generated by the LLM, feel free to modify the relevant prompt in "./prompts/" folder.
# - You may view the reward by printing "env.latest_reward". These are computed by RLBench for each task.
# - To inspect in viewer without performing any action, you may call "env.rlbench_env._scene.step()" in a loop.

# %%
# # uncomment this to show all available tasks in rlbench
# # NOTE: in order to run a new task, you need to add the list of objects (and their corresponding env names) to the "task_object_names.json" file. See README for more details.
# print([task for task in dir(tasks) if task[0].isupper() and not '_' in task])

# %%
# below are the tasks that have object names added to the "task_object_names.json" file
# uncomment one to use
env.load_task(tasks.PutRubbishInBin)
# env.load_task(tasks.LampOff)
# env.load_task(tasks.OpenWineBottle)
# env.load_task(tasks.PushButton)
# env.load_task(tasks.TakeOffWeighingScales)
# env.load_task(tasks.MeatOffGrill)
# env.load_task(tasks.SlideBlockToTarget)
# env.load_task(tasks.TakeLidOffSaucepan)
# env.load_task(tasks.TakeUmbrellaOutOfUmbrellaStand)

descriptions, obs = env.reset()
set_lmp_objects(lmps, env.get_object_names())  # set the object names to be used by voxposer

# %%
instruction = np.random.choice(descriptions)
voxposer_ui(instruction)
# Out:
# *** OpenAI API call took 3.31s ***
# ########################################
# ## "planner" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: put rubbish in bin.
# composer("grasp the rubbish")
# composer("back to default pose")
# composer("move to 10cm on top of the bin")
# composer("open gripper")
# composer("back to default pose")
# # done
#
#
# *** OpenAI API call took 3.79s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: grasp the rubbish.
# movable = parse_query_obj('gripper')
# affordance_map = get_affordance_map('a point at the center of the rubbish')
# gripper_map = get_gripper_map('open everywhere except 1cm around the rubbish')
# execute(movable, affordance_map=affordance_map, gripper_map=gripper_map)
#
#
# *** OpenAI API call took 1.30s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 2.72s ***
# ########################################
# ## "get_affordance_map" generated code
# ########################################
# # Query: a point at the center of the rubbish.
# affordance_map = get_empty_affordance_map()
# rubbish = parse_query_obj('rubbish')
# x, y, z = rubbish.position
# affordance_map[x, y, z] = 1
# ret_val = affordance_map
#
#
# *** OpenAI API call took 5.37s ***
# ########################################
# ## "get_gripper_map" generated code
# ########################################
# # Query: open everywhere except 1cm around the rubbish.
# gripper_map = get_empty_gripper_map()
# # open everywhere
# gripper_map[:, :, :] = 1
# # close when 1cm around the rubbish
# rubbish = parse_query_obj('rubbish')
# set_voxel_by_radius(gripper_map, rubbish.position, radius_cm=1, value=0)
# ret_val = gripper_map
#
#
# *** OpenAI API call took 1.38s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: rubbish.
# rubbish = detect('rubbish')
# ret_val = rubbish
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: rubbish.
# rubbish = detect('rubbish')
# ret_val = rubbish
#
#
# [planners.py | 22:21:32.626] start
# [planners.py | 22:21:32.717] start optimizing, start_pos: [52 49 71]
# [planners.py | 22:21:32.740] optimization finished; path length: 36
# [planners.py | 22:21:32.750] after postprocessing, path length: 36
# [planners.py | 22:21:32.750] last waypoint: [61.15595709 61.93958216  1.        ]
# [interfaces.py | 22:21:32] planner time: 0.125s
# [interfaces.py | 22:21:32] overwriting gripper to less common value for the last waypoint
# ** saving visualization to ./visualizations/22:21:32.html ...
# ** saving visualization to ./visualizations/latest.html ...
# ** save to ./visualizations/22:21:32.html
# [interfaces.py | 22:21:32] start executing path via controller (38 waypoints)
# [interfaces.py | 22:21:33] completed waypoint 1 (wp: [ 0.276 -0.019  1.469], actual: [ 0.277 -0.018  1.469], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.736)
# [interfaces.py | 22:21:33] completed waypoint 2 (wp: [0.302 0.022 1.449], actual: [0.301 0.02  1.449], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.706)
# [interfaces.py | 22:21:33] completed waypoint 3 (wp: [0.323 0.056 1.429], actual: [0.322 0.055 1.429], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.678)
# [interfaces.py | 22:21:33] completed waypoint 4 (wp: [0.34  0.084 1.409], actual: [0.34  0.084 1.408], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.652)
# [interfaces.py | 22:21:33] completed waypoint 5 (wp: [0.353 0.108 1.388], actual: [0.352 0.106 1.389], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.63)
# [interfaces.py | 22:21:33] completed waypoint 6 (wp: [0.363 0.127 1.368], actual: [0.362 0.125 1.369], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.608)
# [interfaces.py | 22:21:33] completed waypoint 7 (wp: [0.37  0.141 1.348], actual: [0.37  0.141 1.348], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.586)
# [interfaces.py | 22:21:33] completed waypoint 8 (wp: [0.374 0.152 1.328], actual: [0.374 0.152 1.327], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.566)
# [interfaces.py | 22:21:34] completed waypoint 9 (wp: [0.377 0.16  1.308], actual: [0.377 0.16  1.307], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.545)
# [interfaces.py | 22:21:34] completed waypoint 10 (wp: [0.377 0.165 1.287], actual: [0.377 0.165 1.287], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.525)
# [interfaces.py | 22:21:34] completed waypoint 11 (wp: [0.377 0.17  1.257], actual: [0.377 0.17  1.257], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.495)
# [interfaces.py | 22:21:34] completed waypoint 12 (wp: [0.376 0.171 1.237], actual: [0.376 0.171 1.236], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.474)
# [interfaces.py | 22:21:34] completed waypoint 13 (wp: [0.374 0.171 1.217], actual: [0.374 0.171 1.216], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.454)
# [interfaces.py | 22:21:34] completed waypoint 14 (wp: [0.373 0.17  1.196], actual: [0.373 0.17  1.197], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.435)
# [interfaces.py | 22:21:34] completed waypoint 15 (wp: [0.371 0.169 1.176], actual: [0.371 0.169 1.177], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.414)
# [interfaces.py | 22:21:35] completed waypoint 16 (wp: [0.371 0.169 1.156], actual: [0.371 0.169 1.156], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.394)
# [interfaces.py | 22:21:35] completed waypoint 17 (wp: [0.371 0.169 1.136], actual: [0.371 0.169 1.135], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.373)
# [interfaces.py | 22:21:35] completed waypoint 18 (wp: [0.372 0.171 1.116], actual: [0.371 0.17  1.116], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.354)
# [interfaces.py | 22:21:35] completed waypoint 19 (wp: [0.372 0.172 1.095], actual: [0.372 0.172 1.095], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.333)
# [interfaces.py | 22:21:35] completed waypoint 20 (wp: [0.372 0.174 1.075], actual: [0.372 0.174 1.076], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.314)
# [interfaces.py | 22:21:35] completed waypoint 21 (wp: [0.373 0.176 1.055], actual: [0.373 0.176 1.056], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.294)
# [interfaces.py | 22:21:35] completed waypoint 22 (wp: [0.374 0.177 1.035], actual: [0.374 0.177 1.035], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.274)
# [interfaces.py | 22:21:35] completed waypoint 23 (wp: [0.376 0.178 1.015], actual: [0.376 0.178 1.015], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.253)
# [interfaces.py | 22:21:36] completed waypoint 24 (wp: [0.378 0.178 0.994], actual: [0.378 0.178 0.995], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.233)
# [interfaces.py | 22:21:36] completed waypoint 25 (wp: [0.38  0.178 0.974], actual: [0.38  0.178 0.975], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.213)
# [interfaces.py | 22:21:36] completed waypoint 26 (wp: [0.383 0.177 0.954], actual: [0.382 0.177 0.955], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.193)
# [interfaces.py | 22:21:36] completed waypoint 27 (wp: [0.384 0.176 0.944], actual: [0.383 0.176 0.944], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.182)
# [interfaces.py | 22:21:36] completed waypoint 28 (wp: [0.386 0.175 0.924], actual: [0.386 0.175 0.924], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.163)
# [interfaces.py | 22:21:36] completed waypoint 29 (wp: [0.388 0.173 0.904], actual: [0.387 0.173 0.905], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.143)
# [interfaces.py | 22:21:36] completed waypoint 30 (wp: [0.389 0.171 0.883], actual: [0.388 0.171 0.885], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.124)
# [interfaces.py | 22:21:36] completed waypoint 31 (wp: [0.389 0.169 0.863], actual: [0.389 0.169 0.864], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.103)
# [interfaces.py | 22:21:37] completed waypoint 32 (wp: [0.389 0.167 0.843], actual: [0.388 0.167 0.844], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.083)
# [interfaces.py | 22:21:37] completed waypoint 33 (wp: [0.387 0.166 0.823], actual: [0.387 0.166 0.823], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.063)
# [interfaces.py | 22:21:37] completed waypoint 34 (wp: [0.384 0.165 0.803], actual: [0.384 0.165 0.803], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.042)
# [interfaces.py | 22:21:37] completed waypoint 35 (wp: [0.38  0.164 0.782], actual: [0.38  0.164 0.783], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.022)
# [interfaces.py | 22:21:37] skip waypoint 36 because it is moving in opposite direction of the final target
# [interfaces.py | 22:21:37] skip waypoint 37 because it is moving in opposite direction of the final target
# [interfaces.py | 22:21:37] completed waypoint 38 (wp: [0.374 0.165 0.762], actual: [0.374 0.165 0.763], target: [0.374 0.165 0.762], start: [ 0.276 -0.019  1.469], dist2target: 0.001)
# [interfaces.py | 22:21:37] reached target; terminating
# [interfaces.py | 22:21:37] finished executing path via controller
# *** OpenAI API call took 1.44s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: back to default pose.
# reset_to_default_pose()
#
#
# *** OpenAI API call took 2.71s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: move to 10cm on top of the bin.
# movable = parse_query_obj('gripper')
# affordance_map = get_affordance_map('a point 10cm above the bin')
# execute(movable, affordance_map=affordance_map)
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 9.64s ***
# ########################################
# ## "get_affordance_map" generated code
# ########################################
# # Query: a point 10cm above the bin.
# affordance_map = get_empty_affordance_map()
# bin = parse_query_obj('bin')
# (min_x, min_y, min_z), (max_x, max_y, max_z) = bin.aabb
# center_x, center_y, center_z = bin.position
# # 10cm above so we add to z-axis
# x = center_x
# y = center_y
# z = max_z + cm2index(10, 'z')
# affordance_map[x, y, z] = 1
# ret_val = affordance_map
#
#
# *** OpenAI API call took 2.11s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: bin.
# bin = detect('bin')
# ret_val = bin
#
#
# [planners.py | 22:21:55.618] start
# [planners.py | 22:21:55.705] start optimizing, start_pos: [52 49 71]
# [planners.py | 22:21:55.720] optimization finished; path length: 22
# [planners.py | 22:21:55.720] after postprocessing, path length: 22
# [planners.py | 22:21:55.720] last waypoint: [59.29181254 31.9312253  29.        ]
# [interfaces.py | 22:21:55] planner time: 0.105s
# ** saving visualization to ./visualizations/22:21:55.html ...
# ** saving visualization to ./visualizations/latest.html ...
# ** save to ./visualizations/22:21:55.html
# [interfaces.py | 22:21:55] start executing path via controller (24 waypoints)
# [interfaces.py | 22:21:56] completed waypoint 1 (wp: [0.282 0.007 1.469], actual: [0.282 0.006 1.469], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.492)
# [interfaces.py | 22:21:56] completed waypoint 2 (wp: [ 0.302 -0.032  1.449], actual: [ 0.301 -0.031  1.449], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.454)
# [interfaces.py | 22:21:56] completed waypoint 3 (wp: [ 0.318 -0.066  1.429], actual: [ 0.318 -0.065  1.429], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.42)
# [interfaces.py | 22:21:56] completed waypoint 4 (wp: [ 0.331 -0.097  1.409], actual: [ 0.33  -0.096  1.409], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.389)
# [interfaces.py | 22:21:56] completed waypoint 5 (wp: [ 0.341 -0.124  1.388], actual: [ 0.341 -0.124  1.388], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.36)
# [interfaces.py | 22:21:56] completed waypoint 6 (wp: [ 0.348 -0.148  1.368], actual: [ 0.348 -0.148  1.368], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.334)
# [interfaces.py | 22:21:56] completed waypoint 7 (wp: [ 0.353 -0.169  1.348], actual: [ 0.353 -0.169  1.347], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.309)
# [interfaces.py | 22:21:57] completed waypoint 8 (wp: [ 0.355 -0.187  1.328], actual: [ 0.355 -0.186  1.327], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.286)
# [interfaces.py | 22:21:57] completed waypoint 9 (wp: [ 0.356 -0.201  1.308], actual: [ 0.357 -0.201  1.307], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.264)
# [interfaces.py | 22:21:57] completed waypoint 10 (wp: [ 0.356 -0.213  1.287], actual: [ 0.356 -0.213  1.287], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.243)
# [interfaces.py | 22:21:57] completed waypoint 11 (wp: [ 0.355 -0.227  1.257], actual: [ 0.355 -0.227  1.257], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.212)
# [interfaces.py | 22:21:57] completed waypoint 12 (wp: [ 0.353 -0.233  1.237], actual: [ 0.353 -0.233  1.237], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.192)
# [interfaces.py | 22:21:57] completed waypoint 13 (wp: [ 0.352 -0.235  1.227], actual: [ 0.352 -0.235  1.226], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.181)
# [interfaces.py | 22:21:57] completed waypoint 14 (wp: [ 0.351 -0.236  1.207], actual: [ 0.351 -0.236  1.207], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.162)
# [interfaces.py | 22:21:57] completed waypoint 15 (wp: [ 0.35  -0.236  1.186], actual: [ 0.35  -0.236  1.187], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.142)
# [interfaces.py | 22:21:58] completed waypoint 16 (wp: [ 0.349 -0.235  1.166], actual: [ 0.349 -0.235  1.166], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.121)
# [interfaces.py | 22:21:58] completed waypoint 17 (wp: [ 0.349 -0.233  1.146], actual: [ 0.349 -0.233  1.146], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.101)
# [interfaces.py | 22:21:58] completed waypoint 18 (wp: [ 0.348 -0.231  1.126], actual: [ 0.348 -0.231  1.125], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.081)
# [interfaces.py | 22:21:58] completed waypoint 19 (wp: [ 0.349 -0.23   1.106], actual: [ 0.348 -0.23   1.105], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.061)
# [interfaces.py | 22:21:58] completed waypoint 20 (wp: [ 0.35  -0.23   1.085], actual: [ 0.349 -0.229  1.086], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.041)
# [interfaces.py | 22:21:58] completed waypoint 21 (wp: [ 0.351 -0.23   1.065], actual: [ 0.351 -0.23   1.066], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.021)
# [interfaces.py | 22:21:58] skip waypoint 22 because it is moving in opposite direction of the final target
# [interfaces.py | 22:21:58] skip waypoint 23 because it is moving in opposite direction of the final target
# [interfaces.py | 22:21:58] completed waypoint 24 (wp: [ 0.354 -0.232  1.045], actual: [ 0.353 -0.232  1.045], target: [ 0.354 -0.232  1.045], start: [0.282 0.007 1.469], dist2target: 0.001)
# [interfaces.py | 22:21:58] reached target; terminating
# [interfaces.py | 22:21:58] finished executing path via controller
# *** OpenAI API call took 1.79s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: open gripper.
# movable = parse_query_obj('gripper')
# gripper_map = get_gripper_map('open everywhere')
# execute(movable, gripper_map=gripper_map)
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 2.31s ***
# ########################################
# ## "get_gripper_map" generated code
# ########################################
# # Query: open everywhere.
# gripper_map = get_empty_gripper_map()
# # open everywhere
# gripper_map[:, :, :] = 1
# ret_val = gripper_map
#
#
# [interfaces.py | 22:22:2] finished executing path via controller
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: back to default pose.
# reset_to_default_pose()
